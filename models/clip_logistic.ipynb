# %%
# Run the following cell if using Google Colab

from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/cs340/project

# !pip install git+https://github.com/openai/CLIP.git
# !pip install cuml-cu12

# %%
import clip_feature_extractor
import numpy as np

from sklearn.model_selection import KFold
from cuml.linear_model import LogisticRegression as cuLogisticRegression
from cuml.preprocessing import StandardScaler as cuStandardScaler
import cupy as cp
import cudf

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/tonyxdsu/.local/lib/python3.12/site-packages/cudf/utils/_ptxcompiler.py:64: UserWarning: Error getting driver and runtime versions:
#
# stdout:
#
#
#
# stderr:
#
# Traceback (most recent call last):
#   File "/home/tonyxdsu/.local/lib/python3.12/site-packages/numba/cuda/cudadrv/driver.py", line 254, in ensure_initialized
#     self.cuInit(0)
#   File "/home/tonyxdsu/.local/lib/python3.12/site-packages/numba/cuda/cudadrv/driver.py", line 327, in safe_cuda_api_call
#     self._check_ctypes_error(fname, retcode)
#   File "/home/tonyxdsu/.local/lib/python3.12/site-packages/numba/cuda/cudadrv/driver.py", line 395, in _check_ctypes_error
#     raise CudaAPIError(retcode, msg)
# numba.cuda.cudadrv.driver.CudaAPIError: [100] Call to cuInit results in CUDA_ERROR_NO_DEVICE
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 4, in <module>
#   File "/home/tonyxdsu/.local/lib/python3.12/site-packages/numba/cuda/cudadrv/driver.py", line 292, in __getattr__
#     self.ensure_initialized()
#   File "/home/tonyxdsu/.local/lib/python3.12/site-packages/numba/cuda/cudadrv/driver.py", line 258, in ensure_initialized
#     raise CudaSupportError(f"Error at driver init: {description}")
# numba.cuda.cudadrv.error.CudaSupportError: Error at driver init: Call to cuInit results in CUDA_ERROR_NO_DEVICE (100)
#
#
# Not patching Numba
#   warnings.warn(msg, UserWarning)

# %%
def cuml_logreg_hyperpram_search(
    X_train, y_train, X_test, y_test,
    C_start=-4, C_stop=4, num_C=20, C_values=None,
    penalties=['l2', 'l1'], n_splits=2, max_iter=1000, verbose=False
):
    """
    Trains logistic regression models using RAPIDS cuML with hyperparameter tuning.

    Parameters:
    - X_train: Training features (NumPy or cuPy array)
    - y_train: Training labels (NumPy or cuPy array)
    - X_test: Testing features (NumPy or cuPy array)
    - y_test: Testing labels (NumPy or cuPy array)
    - C_start: Starting exponent for C values in logspace (default: -4)
    - C_stop: Ending exponent for C values in logspace (default: 4)
    - num_C: Number of C values to generate (default: 10)
    - C_values: Custom array of C values (overrides C_start, C_stop, num_C if provided)
    - penalties: List of penalties to try (default: ['l2', 'l1'])
    - n_splits: Number of splits for cross-validation (default: 2)
    - max_iter: Maximum number of iterations for the solver (default: 1000)
    - verbose: Whether to print progress during training (default: False)

    Returns:
    - best_model: The trained cuML LogisticRegression model with the best hyperparameters
    - best_params: Dictionary of the best hyperparameters
    - best_score: Best cross-validation score achieved during hyperparameter tuning
    - test_score: Accuracy of the best model on the test set
    """
    # Convert data to cuPy arrays if they are not already
    if not isinstance(X_train, cp.ndarray):
        X_train = cp.asarray(X_train)
    if not isinstance(y_train, cp.ndarray):
        y_train = cp.asarray(y_train)
    if not isinstance(X_test, cp.ndarray):
        X_test = cp.asarray(X_test)
    if not isinstance(y_test, cp.ndarray):
        y_test = cp.asarray(y_test)

    # Scale the data using cuML's StandardScaler
    scaler = cuStandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    if C_values is None:
        C_values = cp.logspace(C_start, C_stop, num=num_C)
    else:
        C_values = cp.asarray(C_values)

    total_models = len(C_values) * len(penalties) * n_splits
    print(f"Total number of models to train: {total_models}")

    best_score = -cp.inf
    best_params = None

    kf = KFold(n_splits, shuffle=True, random_state=42)

    for C in C_values:
        for penalty in penalties:
            cv_scores = []

            if verbose:
                print(f"  Training model with C={C}, penalty={penalty}")

            for train_index, val_index in kf.split(X_train_scaled):
                X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
                y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

                # Initialize and train the model
                model = cuLogisticRegression(penalty=penalty, C=C.item(), max_iter=max_iter)
                model.fit(X_train_fold, y_train_fold)

                # Evaluate on validation set
                score = model.score(X_val_fold, y_val_fold)
                cv_scores.append(score)

            mean_cv_score = cp.mean(cp.array(cv_scores))

            if mean_cv_score > best_score:
                best_score = mean_cv_score
                best_params = {'C': C.item(), 'penalty': penalty, 'max_iter': max_iter}
                print(f">> New best score: {best_score}, with params: {best_params}")

    print(f"Best parameters found: {best_params}")
    print(f"Best cross-validation score: {best_score}")

    # Train/test the best model on the entire set
    best_model = cuLogisticRegression(**best_params)
    best_model.fit(X_train_scaled, y_train)

    test_score = best_model.score(X_test_scaled, y_test)
    print(f"Test set accuracy: {test_score}")

    return best_model, best_params, best_score, test_score

# %% [markdown]
# # CIFAR10

# %%
X_train_CIFAR10, y_train_CIFAR10, X_test_CIFAR10, y_test_CIFAR10 = clip_feature_extractor.get_CIFAR10_features()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Loaded features from disk.

# %% [markdown]
# # CIFAR100

# %%
X_train_CIFAR100, y_train_CIFAR100, X_test_CIFAR100, y_test_CIFAR100 = clip_feature_extractor.get_CIFAR100_features()

# %%
# Broad search logistic regression on CIFAR100
best_model, best_params, best_score, test_score = cuml_logreg_hyperpram_search(
    X_train_CIFAR100, y_train_CIFAR100, X_test_CIFAR100, y_test_CIFAR100)
# Out:
# New best score: 0.7041399776935577, with params: {'C': 9.999999999999999e-05, 'penalty': 'l2', 'max_iter': 1000}
# New best score: 0.7637400031089783, with params: {'C': 0.000774263682681127, 'penalty': 'l2', 'max_iter': 1000}
# New best score: 0.7898200154304504, with params: {'C': 0.00599484250318941, 'penalty': 'l2', 'max_iter': 1000}
# [W] [02:55:26.102354] QWL-QN: max iterations reached
# [W] [02:55:26.103728] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:55:57.716029] QWL-QN: max iterations reached
# [W] [02:55:57.718227] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:57:14.576602] QWL-QN: max iterations reached
# [W] [02:57:14.577820] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:57:46.237583] QWL-QN: max iterations reached
# [W] [02:57:46.252418] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:58:20.486460] L-BFGS: max iterations reached
# [W] [02:58:20.492320] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:58:54.423244] L-BFGS: max iterations reached
# [W] [02:58:54.425896] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:59:26.115306] QWL-QN: max iterations reached
# [W] [02:59:26.120067] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [02:59:57.831149] QWL-QN: max iterations reached
# [W] [02:59:57.833008] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:00:33.385563] L-BFGS: max iterations reached
# [W] [03:00:33.390659] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:01:08.355181] L-BFGS: max iterations reached
# [W] [03:01:08.360468] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:01:40.128142] QWL-QN: max iterations reached
# [W] [03:01:40.130575] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:02:12.102674] QWL-QN: max iterations reached
# [W] [03:02:12.104663] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:02:48.396249] L-BFGS: max iterations reached
# [W] [03:02:48.401063] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:03:25.147728] L-BFGS: max iterations reached
# [W] [03:03:25.155608] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:03:56.952306] QWL-QN: max iterations reached
# [W] [03:03:56.954768] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:04:28.806526] QWL-QN: max iterations reached
# [W] [03:04:28.813160] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# Best parameters found: {'C': 0.00599484250318941, 'penalty': 'l2', 'max_iter': 1000}
# Best cross-validation score: 0.7898200154304504
# Test set accuracy: 0.8003000020980835

# %%
# Each model takes between 2s in the best case of fast convergence on a T4 GPU and
# up to 18s in the case of hitting max_iter = 1000 non-convergence

# Broad search yielded:
# Best parameters found: {'C': 0.00599484250318941, 'penalty': 'l2', 'max_iter': 1000}
# Best cross-validation score: 0.7898200154304504
# Test set accuracy: 0.8003000020980835

# Now perform narrower search around found value (though we are biased towards C=0.316 and l2 reg provided by OpenAI for CIFAR100)
best_model, best_params, best_score, test_score = cuml_logreg_hyperpram_search(
    X_train_CIFAR100, y_train_CIFAR100, X_test_CIFAR100, y_test_CIFAR100,
    C_start=-3, C_stop=0, num_C=40, C_values=None,
    penalties=['l2', 'l1'], n_splits=2, max_iter=1000, verbose=True
    )
# Out:
# Total number of models to train: 160
#   Training model with C=0.001, penalty=l2
# New best score: 0.7685000002384186, with params: {'C': 0.001, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.001, penalty=l1
#   Training model with C=0.0011937766417144371, penalty=l2
# New best score: 0.771340012550354, with params: {'C': 0.0011937766417144371, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0011937766417144371, penalty=l1
#   Training model with C=0.0014251026703029977, penalty=l2
# New best score: 0.7743000090122223, with params: {'C': 0.0014251026703029977, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0014251026703029977, penalty=l1
# [W] [03:40:50.640331] QWL-QN stopped, because the line search failed to advance (step delta = 0.000000)
#   Training model with C=0.0017012542798525892, penalty=l2
# New best score: 0.776960015296936, with params: {'C': 0.0017012542798525892, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0017012542798525892, penalty=l1
#   Training model with C=0.002030917620904735, penalty=l2
# New best score: 0.7794999778270721, with params: {'C': 0.002030917620904735, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.002030917620904735, penalty=l1
#   Training model with C=0.0024244620170823287, penalty=l2
# New best score: 0.7822400033473969, with params: {'C': 0.0024244620170823287, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0024244620170823287, penalty=l1
#   Training model with C=0.0028942661247167516, penalty=l2
# New best score: 0.7844400107860565, with params: {'C': 0.0028942661247167516, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0028942661247167516, penalty=l1
#   Training model with C=0.003455107294592218, penalty=l2
# New best score: 0.7862600088119507, with params: {'C': 0.003455107294592218, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.003455107294592218, penalty=l1
#   Training model with C=0.004124626382901352, penalty=l2
# New best score: 0.7876599729061127, with params: {'C': 0.004124626382901352, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.004124626382901352, penalty=l1
#   Training model with C=0.004923882631706742, penalty=l2
# New best score: 0.7892000079154968, with params: {'C': 0.004923882631706742, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.004923882631706742, penalty=l1
#   Training model with C=0.0058780160722749115, penalty=l2
# New best score: 0.7894600033760071, with params: {'C': 0.0058780160722749115, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0058780160722749115, penalty=l1
#   Training model with C=0.00701703828670383, penalty=l2
# New best score: 0.7903800010681152, with params: {'C': 0.00701703828670383, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.00701703828670383, penalty=l1
#   Training model with C=0.008376776400682923, penalty=l2
# New best score: 0.7907399833202362, with params: {'C': 0.008376776400682923, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.008376776400682923, penalty=l1
#   Training model with C=0.01, penalty=l2
#   Training model with C=0.01, penalty=l1
#   Training model with C=0.01193776641714437, penalty=l2
#   Training model with C=0.01193776641714437, penalty=l1
#   Training model with C=0.014251026703029987, penalty=l2
#   Training model with C=0.014251026703029987, penalty=l1
#   Training model with C=0.01701254279852589, penalty=l2
#   Training model with C=0.01701254279852589, penalty=l1
#   Training model with C=0.020309176209047358, penalty=l2
#   Training model with C=0.020309176209047358, penalty=l1
#   Training model with C=0.02424462017082328, penalty=l2
#   Training model with C=0.02424462017082328, penalty=l1
#   Training model with C=0.028942661247167517, penalty=l2
#   Training model with C=0.028942661247167517, penalty=l1
#   Training model with C=0.034551072945922204, penalty=l2
#   Training model with C=0.034551072945922204, penalty=l1
#   Training model with C=0.04124626382901352, penalty=l2
#   Training model with C=0.04124626382901352, penalty=l1
#   Training model with C=0.04923882631706741, penalty=l2
#   Training model with C=0.04923882631706741, penalty=l1
#   Training model with C=0.05878016072274915, penalty=l2
#   Training model with C=0.05878016072274915, penalty=l1
#   Training model with C=0.07017038286703829, penalty=l2
#   Training model with C=0.07017038286703829, penalty=l1
#   Training model with C=0.0837677640068292, penalty=l2
#   Training model with C=0.0837677640068292, penalty=l1
#   Training model with C=0.10000000000000002, penalty=l2
#   Training model with C=0.10000000000000002, penalty=l1
#   Training model with C=0.1193776641714437, penalty=l2
#   Training model with C=0.1193776641714437, penalty=l1
#   Training model with C=0.14251026703029984, penalty=l2
#   Training model with C=0.14251026703029984, penalty=l1
#   Training model with C=0.1701254279852589, penalty=l2
#   Training model with C=0.1701254279852589, penalty=l1
#   Training model with C=0.20309176209047364, penalty=l2
#   Training model with C=0.20309176209047364, penalty=l1
#   Training model with C=0.24244620170823294, penalty=l2
#   Training model with C=0.24244620170823294, penalty=l1
#   Training model with C=0.2894266124716752, penalty=l2
#   Training model with C=0.2894266124716752, penalty=l1
#   Training model with C=0.345510729459222, penalty=l2
#   Training model with C=0.345510729459222, penalty=l1
#   Training model with C=0.41246263829013535, penalty=l2
#   Training model with C=0.41246263829013535, penalty=l1
# [W] [03:54:09.425370] QWL-QN: max iterations reached
# [W] [03:54:09.428506] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:54:41.274554] QWL-QN: max iterations reached
# [W] [03:54:41.276431] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=0.49238826317067413, penalty=l2
#   Training model with C=0.49238826317067413, penalty=l1
# [W] [03:55:33.064851] QWL-QN: max iterations reached
# [W] [03:55:33.069541] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:56:04.711128] QWL-QN: max iterations reached
# [W] [03:56:04.717491] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=0.5878016072274915, penalty=l2
#   Training model with C=0.5878016072274915, penalty=l1
# [W] [03:56:57.395330] QWL-QN: max iterations reached
# [W] [03:56:57.397438] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:57:29.004031] QWL-QN: max iterations reached
# [W] [03:57:29.006054] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=0.7017038286703831, penalty=l2
#   Training model with C=0.7017038286703831, penalty=l1
# [W] [03:58:23.273916] QWL-QN: max iterations reached
# [W] [03:58:23.275979] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [03:58:54.954011] QWL-QN: max iterations reached
# [W] [03:58:54.966973] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=0.8376776400682922, penalty=l2
#   Training model with C=0.8376776400682922, penalty=l1
# [W] [03:59:51.943368] QWL-QN: max iterations reached
# [W] [03:59:51.946847] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:00:23.535800] QWL-QN: max iterations reached
# [W] [04:00:23.538725] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=1.0, penalty=l2
#   Training model with C=1.0, penalty=l1
# [W] [04:01:19.702073] QWL-QN: max iterations reached
# [W] [04:01:19.704220] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:01:51.292648] QWL-QN: max iterations reached
# [W] [04:01:51.294619] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# Best parameters found: {'C': 0.008376776400682923, 'penalty': 'l2', 'max_iter': 1000}
# Best cross-validation score: 0.7907399833202362
# Test set accuracy: 0.8022000193595886

# %% [markdown]
# # MNIST

# %%
# Extract features of MNIST
X_train_MNIST, y_train_MNIST, X_test_MNIST, y_test_MNIST = clip_feature_extractor.get_MNIST_features()
# Out:
# Using device: cuda
# Extracting features: 100%|██████████| 600/600 [02:54<00:00,  3.43it/s]
# Using device: cuda
# Extracting features: 100%|██████████| 100/100 [00:28<00:00,  3.55it/s]

# %%
# perform broad search on MNIST
best_model, best_params, best_score, test_score = cuml_logreg_hyperpram_search(
    X_train_MNIST, y_train_MNIST, X_test_MNIST, y_test_MNIST, num_C=40, verbose=True)
# Out:
# Total number of models to train: 160
#   Training model with C=9.999999999999999e-05, penalty=l2
# >> New best score: 0.9599500000476837, with params: {'C': 9.999999999999999e-05, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=9.999999999999999e-05, penalty=l1
#   Training model with C=0.0001603718743751331, penalty=l2
# >> New best score: 0.964983344078064, with params: {'C': 0.0001603718743751331, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0001603718743751331, penalty=l1
# [W] [04:32:46.839278] QWL-QN stopped, because the line search failed to advance (step delta = 0.000000)
#   Training model with C=0.00025719138090593444, penalty=l2
# >> New best score: 0.9691666662693024, with params: {'C': 0.00025719138090593444, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.00025719138090593444, penalty=l1
#   Training model with C=0.0004124626382901352, penalty=l2
# >> New best score: 0.9724000096321106, with params: {'C': 0.0004124626382901352, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0004124626382901352, penalty=l1
#   Training model with C=0.0006614740641230145, penalty=l2
# >> New best score: 0.9749333262443542, with params: {'C': 0.0006614740641230145, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0006614740641230145, penalty=l1
#   Training model with C=0.001060818355139448, penalty=l2
# >> New best score: 0.9775833487510681, with params: {'C': 0.001060818355139448, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.001060818355139448, penalty=l1
#   Training model with C=0.0017012542798525892, penalty=l2
# >> New best score: 0.9796999990940094, with params: {'C': 0.0017012542798525892, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0017012542798525892, penalty=l1
#   Training model with C=0.002728333376486767, penalty=l2
# >> New best score: 0.9815333187580109, with params: {'C': 0.002728333376486767, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.002728333376486767, penalty=l1
#   Training model with C=0.004375479375074184, penalty=l2
# >> New best score: 0.9828333258628845, with params: {'C': 0.004375479375074184, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.004375479375074184, penalty=l1
#   Training model with C=0.00701703828670383, penalty=l2
# >> New best score: 0.984333336353302, with params: {'C': 0.00701703828670383, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.00701703828670383, penalty=l1
#   Training model with C=0.011253355826007646, penalty=l2
# >> New best score: 0.9850666522979736, with params: {'C': 0.011253355826007646, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.011253355826007646, penalty=l1
#   Training model with C=0.018047217668271703, penalty=l2
# >> New best score: 0.9857333302497864, with params: {'C': 0.018047217668271703, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.018047217668271703, penalty=l1
#   Training model with C=0.028942661247167503, penalty=l2
# >> New best score: 0.986133337020874, with params: {'C': 0.028942661247167503, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.028942661247167503, penalty=l1
#   Training model with C=0.046415888336127774, penalty=l2
# >> New best score: 0.9863666594028473, with params: {'C': 0.046415888336127774, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.046415888336127774, penalty=l1
#   Training model with C=0.07443803013251687, penalty=l2
#   Training model with C=0.07443803013251687, penalty=l1
#   Training model with C=0.11937766417144365, penalty=l2
#   Training model with C=0.11937766417144365, penalty=l1
#   Training model with C=0.19144819761699577, penalty=l2
#   Training model with C=0.19144819761699577, penalty=l1
#   Training model with C=0.30702906297578486, penalty=l2
#   Training model with C=0.30702906297578486, penalty=l1
#   Training model with C=0.4923882631706738, penalty=l2
#   Training model with C=0.4923882631706738, penalty=l1
#   Training model with C=0.7896522868499724, penalty=l2
#   Training model with C=0.7896522868499724, penalty=l1
# [W] [04:37:25.847284] QWL-QN: max iterations reached
# [W] [04:37:25.854958] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:37:43.458786] QWL-QN: max iterations reached
# [W] [04:37:43.460705] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=1.266380173467403, penalty=l2
#   Training model with C=1.266380173467403, penalty=l1
# [W] [04:38:15.138645] QWL-QN: max iterations reached
# [W] [04:38:15.140612] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:38:32.753155] QWL-QN: max iterations reached
# [W] [04:38:32.757480] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=2.030917620904735, penalty=l2
#   Training model with C=2.030917620904735, penalty=l1
# [W] [04:39:04.875102] QWL-QN: max iterations reached
# [W] [04:39:04.877171] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:39:22.481155] QWL-QN: max iterations reached
# [W] [04:39:22.486011] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=3.257020655659782, penalty=l2
#   Training model with C=3.257020655659782, penalty=l1
# [W] [04:39:55.828611] QWL-QN: max iterations reached
# [W] [04:39:55.830872] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:40:13.423166] QWL-QN: max iterations reached
# [W] [04:40:13.425091] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=5.22334507426684, penalty=l2
#   Training model with C=5.22334507426684, penalty=l1
# [W] [04:40:47.153519] QWL-QN: max iterations reached
# [W] [04:40:47.155459] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:41:05.817111] QWL-QN: max iterations reached
# [W] [04:41:05.818762] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=8.376776400682916, penalty=l2
#   Training model with C=8.376776400682916, penalty=l1
# [W] [04:41:40.522182] QWL-QN: max iterations reached
# [W] [04:41:40.522619] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:41:58.146880] QWL-QN: max iterations reached
# [W] [04:41:58.148989] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=13.433993325988993, penalty=l2
#   Training model with C=13.433993325988993, penalty=l1
# [W] [04:42:33.541436] QWL-QN: max iterations reached
# [W] [04:42:33.546524] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:42:51.180175] QWL-QN: max iterations reached
# [W] [04:42:51.183678] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=21.54434690031882, penalty=l2
#   Training model with C=21.54434690031882, penalty=l1
# [W] [04:43:27.730409] QWL-QN: max iterations reached
# [W] [04:43:27.732263] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:43:45.354659] QWL-QN: max iterations reached
# [W] [04:43:45.357983] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=34.55107294592218, penalty=l2
#   Training model with C=34.55107294592218, penalty=l1
# [W] [04:44:21.328666] QWL-QN: max iterations reached
# [W] [04:44:21.345224] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:44:38.961748] QWL-QN: max iterations reached
# [W] [04:44:38.963741] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=55.410203300094885, penalty=l2
#   Training model with C=55.410203300094885, penalty=l1
# [W] [04:45:15.442923] QWL-QN: max iterations reached
# [W] [04:45:15.445289] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:45:33.074337] QWL-QN: max iterations reached
# [W] [04:45:33.079991] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=88.86238162743398, penalty=l2
#   Training model with C=88.86238162743398, penalty=l1
# [W] [04:46:11.577252] QWL-QN: max iterations reached
# [W] [04:46:11.579709] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:46:29.209649] QWL-QN: max iterations reached
# [W] [04:46:29.211749] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=142.5102670302998, penalty=l2
#   Training model with C=142.5102670302998, penalty=l1
# [W] [04:47:06.750563] QWL-QN: max iterations reached
# [W] [04:47:06.753173] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:47:24.380828] QWL-QN: max iterations reached
# [W] [04:47:24.386247] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=228.54638641349885, penalty=l2
#   Training model with C=228.54638641349885, penalty=l1
# [W] [04:48:02.033661] QWL-QN: max iterations reached
# [W] [04:48:02.040850] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:48:19.679662] QWL-QN: max iterations reached
# [W] [04:48:19.680733] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=366.5241237079626, penalty=l2
#   Training model with C=366.5241237079626, penalty=l1
# [W] [04:48:58.615345] QWL-QN: max iterations reached
# [W] [04:48:58.616317] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:49:16.250074] QWL-QN: max iterations reached
# [W] [04:49:16.253640] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=587.8016072274912, penalty=l2
#   Training model with C=587.8016072274912, penalty=l1
# [W] [04:49:52.664161] QWL-QN: max iterations reached
# [W] [04:49:52.666508] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:50:10.304613] QWL-QN: max iterations reached
# [W] [04:50:10.306444] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=942.6684551178845, penalty=l2
#   Training model with C=942.6684551178845, penalty=l1
# [W] [04:50:43.544476] QWL-QN: max iterations reached
# [W] [04:50:43.547449] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:51:01.188649] QWL-QN: max iterations reached
# [W] [04:51:01.194272] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=1511.7750706156614, penalty=l2
#   Training model with C=1511.7750706156614, penalty=l1
# [W] [04:51:32.146358] QWL-QN: max iterations reached
# [W] [04:51:32.152971] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:51:49.794878] QWL-QN: max iterations reached
# [W] [04:51:49.796341] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=2424.462017082326, penalty=l2
#   Training model with C=2424.462017082326, penalty=l1
# [W] [04:52:18.289278] QWL-QN: max iterations reached
# [W] [04:52:18.292029] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:52:35.933375] QWL-QN: max iterations reached
# [W] [04:52:35.940999] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=3888.155180308085, penalty=l2
#   Training model with C=3888.155180308085, penalty=l1
# [W] [04:53:03.132214] QWL-QN: max iterations reached
# [W] [04:53:03.134463] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:53:20.771202] QWL-QN: max iterations reached
# [W] [04:53:20.783789] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=6235.507341273912, penalty=l2
#   Training model with C=6235.507341273912, penalty=l1
# [W] [04:53:46.075350] QWL-QN: max iterations reached
# [W] [04:53:46.080758] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:54:03.749559] QWL-QN: max iterations reached
# [W] [04:54:03.751660] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
#   Training model with C=10000.0, penalty=l2
#   Training model with C=10000.0, penalty=l1
# [W] [04:54:28.352338] QWL-QN: max iterations reached
# [W] [04:54:28.353860] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# [W] [04:54:46.021635] QWL-QN: max iterations reached
# [W] [04:54:46.025133] Maximum iterations reached before solver is converged. To increase model accuracy you can increase the number of iterations (max_iter) or improve the scaling of the input data.
# Best parameters found: {'C': 0.046415888336127774, 'penalty': 'l2', 'max_iter': 1000}
# Best cross-validation score: 0.9863666594028473
# Test set accuracy: 0.9889000058174133

# %%
# Narrow search on MNIST around C=0.0464 and l2 loss
best_model, best_params, best_score, test_score = cuml_logreg_hyperpram_search(
    X_train_MNIST, y_train_MNIST, X_test_MNIST, y_test_MNIST, C_start=-2, C_stop=-1, num_C=50, penalties=['l2'], n_splits=4, verbose=True)
# Out:
# Total number of models to train: 200
#   Training model with C=0.01, penalty=l2
# >> New best score: 0.9861833304166794, with params: {'C': 0.01, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.010481131341546858, penalty=l2
# >> New best score: 0.9863499999046326, with params: {'C': 0.010481131341546858, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.010985411419875584, penalty=l2
# >> New best score: 0.9865333288908005, with params: {'C': 0.010985411419875584, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.011513953993264476, penalty=l2
# >> New best score: 0.9866166561841965, with params: {'C': 0.011513953993264476, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.01206792640639329, penalty=l2
# >> New best score: 0.9866499900817871, with params: {'C': 0.01206792640639329, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.012648552168552958, penalty=l2
# >> New best score: 0.9867333322763443, with params: {'C': 0.012648552168552958, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.013257113655901088, penalty=l2
# >> New best score: 0.9868333339691162, with params: {'C': 0.013257113655901088, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.013894954943731374, penalty=l2
# >> New best score: 0.9868499934673309, with params: {'C': 0.013894954943731374, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.014563484775012436, penalty=l2
# >> New best score: 0.9868666678667068, with params: {'C': 0.014563484775012436, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.015264179671752334, penalty=l2
# >> New best score: 0.9869166761636734, with params: {'C': 0.015264179671752334, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.015998587196060583, penalty=l2
# >> New best score: 0.9869666546583176, with params: {'C': 0.015998587196060583, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.016768329368110083, penalty=l2
# >> New best score: 0.9870000034570694, with params: {'C': 0.016768329368110083, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.017575106248547922, penalty=l2
#   Training model with C=0.018420699693267165, penalty=l2
#   Training model with C=0.019306977288832496, penalty=l2
# >> New best score: 0.98703333735466, with params: {'C': 0.019306977288832496, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.020235896477251568, penalty=l2
# >> New best score: 0.9870999902486801, with params: {'C': 0.020235896477251568, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.021209508879201904, penalty=l2
#   Training model with C=0.022229964825261943, penalty=l2
# >> New best score: 0.987133339047432, with params: {'C': 0.022229964825261943, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.02329951810515372, penalty=l2
# >> New best score: 0.987199991941452, with params: {'C': 0.02329951810515372, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.02442053094548651, penalty=l2
# >> New best score: 0.9872999936342239, with params: {'C': 0.02442053094548651, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.02559547922699536, penalty=l2
#   Training model with C=0.02682695795279726, penalty=l2
#   Training model with C=0.028117686979742307, penalty=l2
# >> New best score: 0.9873499870300293, with params: {'C': 0.028117686979742307, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0294705170255181, penalty=l2
# >> New best score: 0.9873666614294052, with params: {'C': 0.0294705170255181, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0308884359647748, penalty=l2
# >> New best score: 0.9874166548252106, with params: {'C': 0.0308884359647748, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.032374575428176434, penalty=l2
# >> New best score: 0.9874166697263718, with params: {'C': 0.032374575428176434, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.03393221771895328, penalty=l2
# >> New best score: 0.9874333441257477, with params: {'C': 0.03393221771895328, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.03556480306223129, penalty=l2
# >> New best score: 0.9875166565179825, with params: {'C': 0.03556480306223129, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.0372759372031494, penalty=l2
#   Training model with C=0.03906939937054617, penalty=l2
#   Training model with C=0.040949150623804255, penalty=l2
#   Training model with C=0.04291934260128778, penalty=l2
#   Training model with C=0.04498432668969444, penalty=l2
# >> New best score: 0.9875499904155731, with params: {'C': 0.04498432668969444, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.04714866363457392, penalty=l2
#   Training model with C=0.04941713361323833, penalty=l2
#   Training model with C=0.0517947467923121, penalty=l2
# >> New best score: 0.987583339214325, with params: {'C': 0.0517947467923121, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.054286754393238594, penalty=l2
# >> New best score: 0.9875999987125397, with params: {'C': 0.054286754393238594, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.056898660290182965, penalty=l2
# >> New best score: 0.9876333177089691, with params: {'C': 0.056898660290182965, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.05963623316594643, penalty=l2
#   Training model with C=0.06250551925273973, penalty=l2
#   Training model with C=0.0655128556859551, penalty=l2
#   Training model with C=0.06866488450043001, penalty=l2
# >> New best score: 0.987666666507721, with params: {'C': 0.06866488450043001, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.07196856730011518, penalty=l2
# >> New best score: 0.9877000004053116, with params: {'C': 0.07196856730011518, 'penalty': 'l2', 'max_iter': 1000}
#   Training model with C=0.07543120063354615, penalty=l2
#   Training model with C=0.07906043210907698, penalty=l2
#   Training model with C=0.08286427728546843, penalty=l2
#   Training model with C=0.08685113737513525, penalty=l2
#   Training model with C=0.09102981779915217, penalty=l2
#   Training model with C=0.0954095476349994, penalty=l2
#   Training model with C=0.1, penalty=l2
# Best parameters found: {'C': 0.07196856730011518, 'penalty': 'l2', 'max_iter': 1000}
# Best cross-validation score: 0.9877000004053116
# Test set accuracy: 0.9886000156402588
